# %%
# !pip install -q resend
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 2.7 MB/s eta 0:00:00

# %%
import os
from getpass import getpass
import resend

# Enter your Resend API Key
os.environ["RESEND_API_KEY"] = getpass("Enter Resend API Key: ")

resend.api_key = os.environ["RESEND_API_KEY"]
# Out:
# Enter Resend API Key: ··········

# %%
response = resend.Emails.send({

    "from": "onboarding@resend.dev",

    "to": "youremail@gmail.com",

    "subject": "Hello from Resend!",

    "html": """
    <h2>🎉 Congratulations!</h2>

    <p>This is my second email.</p>

    <p>Testing before building agents.</p>
    """

})

print(response)
# Out:
# {'id': '1d3a1efd-f114-47f4-ac4e-c9236b50dec1', 'http_headers': {'Date': 'Sat, 20 Jun 2026 00:05:30 GMT', 'Content-Type': 'application/json', 'Content-Length': '45', 'Connection': 'keep-alive', 'ratelimit-limit': '5', 'ratelimit-policy': '5;w=1', 'ratelimit-remaining': '4', 'ratelimit-reset': '1', 'x-resend-daily-quota': '1', 'x-resend-monthly-quota': '1', 'cf-cache-status': 'DYNAMIC', 'Server': 'cloudflare', 'CF-RAY': 'a0e685b139ed6758-ATL'}}
