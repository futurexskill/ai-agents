# %%
# !pip install -q openai-agents

# %%
from agents import Agent, Runner
from getpass import getpass
import os


os.environ["OPENAI_API_KEY"] = getpass("Enter OpenAI API Key: ")
# Out:
# Enter OpenAI API Key: ··········

# %%
agent = Agent(

    name="History Tutor",

    instructions="""
    You answer history questions clearly and concisely.
    """,

    model="gpt-5.5"

)

# %%
result = await Runner.run(

    agent,

    "When did the Roman Empire fall?"

)

print(result.final_output)
# Out:
# The Roman Empire “fell” at different times depending on which half you mean:
#
# - **Western Roman Empire:** traditionally **476 CE**, when the last western emperor, **Romulus Augustulus**, was deposed.
# - **Eastern Roman Empire (Byzantine Empire):** **1453 CE**, when **Constantinople** fell to the Ottoman Turks.

# %%
science_agent = Agent(

    name="Science Tutor",

    instructions="""
    Explain science concepts simply.
    Use examples whenever possible.
    """,

    model="gpt-5.5"

)

# %%
result = await Runner.run(

    science_agent,

    "Why is the sky blue?"

)

print(result.final_output)
# Out:
# The sky looks blue because of how sunlight interacts with air.
#
# Sunlight is made of many colors. When it enters Earth’s atmosphere, tiny air molecules scatter the light in all directions. Blue light scatters more than red or yellow light because it has a shorter wavelength.
#
# So when you look up, you see blue light coming from all across the sky.
#
# Example: It’s like throwing a handful of different-sized balls at a crowd of tiny obstacles—smaller balls get bounced around more easily. Blue light is like those smaller balls, so it spreads everywhere.
