# %%
import requests

url = "https://0e19-34-21-183-179.ngrok-free.app/agent"

payload = {
    "question": "Explain Agentic AI in simple terms."
}

response = requests.post(url, json=payload)

print(response.json())
# Out:
# {'question': 'Explain Agentic AI in simple terms.', 'answer': 'Agentic AI is a type of artificial intelligence that can act on its own to achieve goals. Instead of just following direct instructions, it can make decisions, plan steps, and learn from its actions—like a helpful robot that can figure out problems and work independently.'}
